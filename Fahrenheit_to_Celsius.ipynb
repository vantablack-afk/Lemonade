# %% [markdown]
# **Fahrenhei to Celsius**

# %%
# The welcome
print("Welcome to Victor's Fahrenheit to Celsius converter")

# F temps defined
temp1_f = 32
temp2_f = 100
temp3_f = 599

#Individual formulas for c temps
temp1_c = (temp1_f -32) * 5/9
temp2_c = (temp2_f -32) * 5/9
temp3_c = (temp3_f -32) * 5/9

#Print conversion of fahrenhei to celsius

print(
    f"{temp1_f} degrees Fahrenheit is about equal to {temp1_c: .2f} degrees Celsius."
)
print(
    f"{temp2_f} degrees Fahrenheit is about equal to {temp2_c: .2f} degrees Celsius"
)
print(
    f"{temp3_f} degrees Fahrenheit is about equal to {temp3_c: .2f} degrees Celsius"
)
# Out:
# Welcome to Victor's Fahrenheit to Celsius converter
# 32 degrees Fahrenheit is about equal to  0.00 degrees Celsius.
# 100 degrees Fahrenheit is about equal to  37.78 degrees Celsius
# 599 degrees Fahrenheit is about equal to  315.00 degrees Celsius
